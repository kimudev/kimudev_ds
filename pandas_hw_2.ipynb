# %% [markdown]
# <a href="https://colab.research.google.com/github/kimudev/kimudev_ds/blob/main/pandas_hw_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Задание 1
# Напишите функцию, которая классифицирует фильмы из материалов занятия по правилам:
#
# - оценка 2 и ниже — низкий рейтинг;
# - оценка 4 и ниже — средний рейтинг;
# - оценка 4.5 и 5 — высокий рейтинг.
#
# Результат классификации запишите в столбец class.

# %%
import pandas as pd

movies = pd.read_csv('movies.csv')
ratings = pd.read_csv('ratings.csv')
ratings_of_movies = ratings.merge(movies, on='movieId', how='inner')

ratings_of_movies.head()


def rating_info(param):
  if param <= 2:
    return 'низкий рейтинг'
  elif param <= 4:
    return 'средний рейтинг'
  elif param == 4.5 or param == 5:
    return 'высокий рейтинг'

ratings_of_movies['class'] = ratings_of_movies['rating'].apply(rating_info)

ratings_of_movies.head(50)
# Out:
#     userId  movieId  rating   timestamp                   title  \
# 0        1       31     2.5  1260759144  Dangerous Minds (1995)
# 1        7       31     3.0   851868750  Dangerous Minds (1995)
# 2       31       31     4.0  1273541953  Dangerous Minds (1995)
# 3       32       31     4.0   834828440  Dangerous Minds (1995)
# 4       36       31     3.0   847057202  Dangerous Minds (1995)
# 5       39       31     3.0   832525157  Dangerous Minds (1995)
# 6       73       31     3.5  1255591860  Dangerous Minds (1995)
# 7       88       31     3.0  1239755559  Dangerous Minds (1995)
# 8       96       31     2.5  1223256331  Dangerous Minds (1995)
# 9      110       31     4.0   840100695  Dangerous Minds (1995)
# 10     111       31     3.5  1097429230  Dangerous Minds (1995)
# 11     150       31     2.5  1130905954  Dangerous Minds (1995)
# 12     161       31     3.0   837629820  Dangerous Minds (1995)
# 13     165       31     3.5  1111981801  Dangerous Minds (1995)
# ...

# %% [markdown]
# ## Задание 2
# Используйте файл keywords.csv.
#
# Нужно написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определённому региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#   'Центр': ['москва', 'тула', 'ярославль'],
#   'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#   'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
# }
#
# Результат классификации запишите в отдельный столбец region.

# %%
import pandas as pd

keywords = pd.read_csv('keywords.csv')

geo_data = {
    'Центр': ['москва', 'тула', 'ярославль'],
    'Северо-Запад': ['петербург', 'псков', 'мурманск'],
    'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
}

keywords.head(50)

def find_region(param):
    for key, values in geo_data.items():
        if param in values:
            return key
    return 'undefined'

keywords['region'] = keywords['keyword'].apply(find_region)

keywords[keywords.region == 'Центр'].head()
# Out:
#          keyword   shows region
# 1259      москва  153050  Центр
# 6075   ярославль   41720  Центр
# 11785       тула   23898  Центр
